# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/lcbjrrr/blob/master/Etapa_Visualizacao_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Etapa Visualizacao
#
# ALUNOS:
# Andre Nunes Lipay - RA 202108197157 ;
# João Lucca Santana de Lima - RA 202102305951
#
#
# Planilha de Dados: https://docs.google.com/spreadsheets/d/1JuitRIy4d1hZJAiM8guKBNMfnCC_5y4OWX3vQzOPpSQ/edit?usp=sharing

# %% [markdown]
# 'MesAno: Mês e ano dos dados
#
# OrgaoSup: Órgão composto por todos os ministros do Poder Executivo Federal e teria a função de assessorar o Presidente da República na formulação da Política Nacional e outras diretrizes
#
# OrgaoEntidade: As entidades vinculadas ao Estado possuem administração e orçamentos próprios, porém devem prestar contas de suas ações ao órgão ao qual está ligada.
#
# ValorEmp: O valor que o Estado reservou para efetuar um pagamento planejado (real).
#
# ValorLiq: Quando o serviço for executado esse será o valor liquidado (real).
#
# ValorPag: Quando o fornecedor de fato receber o valor (real).
#
# Restos: São as despesas empenhadas, mas não pagas dentro do exercício financeiro, ou seja, até 31 de dezembro (real).'

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

wb = gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('DadosProg').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
#            0  ...                     6
# 0    Mês Ano  ...  Valor Restos a Pagar
# 1    ago./21  ...       R$ 1.320.862,24
# 2    out./21  ...         R$ 303.506,63
# 3    set./21  ...       R$ 1.486.439,68
# 4    set./21  ...       R$ 2.483.598,24
# ..       ...  ...                   ...
# 704  ago./21  ...       R$ 5.040.885,44
# 705  out./21  ...         R$ 902.716,36
# 706  set./21  ...       R$ 3.261.710,61
# 707  ago./21  ...      R$ 11.557.545,85
# 708  out./21  ...       R$ 1.506.339,15
#
# [709 rows x 7 columns]

# %%
Valor Empenhado
('valor máximo', R$ 339.322.796.039,13)
('valor mínimo', -R$ 1.158.545.934,60)

valor liquidado
('valor máximo', R$ 396.644.643.343,24)
('valor máximo', R$  4.532,00)

valor pago
('valor máximo', R$ 396.644.183.297,60)
('valor mínimo', R$ 1.429,77)

valor restos a pagar
('valor máximo', R$ 324.424.667,93)
('valor mínimo', -R$ 5.664.055,46)

# %% [markdown]
# Valor Empenhado:
#
# Valor Máximo = R$ 339.322.796.039,13
#
# Valor Mínimo = -R$ 1.158.545.934,60
#
# É notável que a escolha de gastar o dinheiro público durante o período foi muito maior do que a de poupar, isso ocorre devido as leis normativas vigentes em que os Órgãos e Entidades que se mantém com verba pública recebem apenas o necessário para a "sobrevivência" e caso não gastem a verba concedida sofrerá uma diminuição de recebidos no próximo momento.

# %% [markdown]
# Valor Liquidado:
#
# Valor Máximo = R$ 396.644.643.343,24
#
# Valor Mínimo = R$  4.532,00
#
# A partir desses números é possível perceber que praticamente toda a verba utilizada é liquidada e apenas em raríssimos casos ocorre uma retratação dessa verba gasta.

# %% [markdown]
# Valor Pago:
#
# Valor Máximo = R$ 396.644.183.297,60
#
# Valor Mínimo = R$ 1.429,77
#
# Diante desses resultados podemos afirmar que os valores reais não diferem muito dos valores empenhados, portanto não há um grande desvio sem a notificação para a Controladoria Geral da União.

# %% [markdown]
# Valor Restos a Pagar:
#
# Valor Máximo = R$ 324.424.667,93
#
# Valor Mínimo = -R$ 5.664.055,46
#
# Visto que os dados são majoritariamente dos meses de Agosto, Setembro e Outubro ainda não são totalmente exploráveis, tal que ao decorer do ano o valor dos restos a pagar tende a aumentar consideravelmente devido ao atraso de pagamentos e recebíveis.

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
wb = gc.open_by_key('1JuitRIy4d1hZJAiM8guKBNMfnCC_5y4OWX3vQzOPpSQ')
ws = wb.worksheet('Valor Empenhado')

# get_all_values gives a list of rows.
rows = ws.get_all_values()


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
#                                                      0                  1
# 0                                       Órgão Superior    Valor Empenhado
# 1                     63000 - Advocacia-Geral da União  R$ 148.289.705,44
# 2                     63000 - Advocacia-Geral da União      R$ 161.777,90
# 3                     63000 - Advocacia-Geral da União  R$ 140.678.260,25
# 4    24000 - Ministério da Ciência, Tecnologia, Ino...    R$ 1.121.508,14
# ..                                                 ...                ...
# 704                     26000 - Ministério da Educação    R$ 8.207.198,83
# 705                     26000 - Ministério da Educação    R$ 3.090.668,92
# 706               39000 - Ministério da Infraestrutura      R$ 150.619,66
# 707               39000 - Ministério da Infraestrutura    R$ 5.658.899,08
# 708               39000 - Ministério da Infraestrutura   R$ 21.637.647,93
#
# [709 rows x 2 columns]

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
wb = gc.open_by_key('1JuitRIy4d1hZJAiM8guKBNMfnCC_5y4OWX3vQzOPpSQ')
ws = wb.worksheet('Valor Liquidado')

# get_all_values gives a list of rows.
rows = ws.get_all_values()


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
#                                                      0                  1
# 0                                       Órgão Superior    Valor Liquidado
# 1                     63000 - Advocacia-Geral da União  R$ 287.757.633,96
# 2                     63000 - Advocacia-Geral da União   R$ 15.875.129,68
# 3                     63000 - Advocacia-Geral da União  R$ 303.140.813,24
# 4    24000 - Ministério da Ciência, Tecnologia, Ino...    R$ 2.693.264,79
# ..                                                 ...                ...
# 704                     26000 - Ministério da Educação   R$ 75.328.132,12
# 705                     26000 - Ministério da Educação    R$ 1.118.626,50
# 706               39000 - Ministério da Infraestrutura   R$ 37.260.134,29
# 707               39000 - Ministério da Infraestrutura   R$ 29.268.245,73
# 708               39000 - Ministério da Infraestrutura    R$ 1.446.168,31
#
# [709 rows x 2 columns]

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
wb = gc.open_by_key('1JuitRIy4d1hZJAiM8guKBNMfnCC_5y4OWX3vQzOPpSQ')
ws = wb.worksheet('Valor Pago')

# get_all_values gives a list of rows.
rows = ws.get_all_values()


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
#                                                      0                  1
# 0                                       Órgão Superior         Valor Pago
# 1                     63000 - Advocacia-Geral da União  R$ 289.488.651,91
# 2                     63000 - Advocacia-Geral da União  R$ 174.846.490,35
# 3                     63000 - Advocacia-Geral da União  R$ 300.550.820,01
# 4    24000 - Ministério da Ciência, Tecnologia, Ino...    R$ 2.693.764,69
# ..                                                 ...                ...
# 704                     26000 - Ministério da Educação   R$ 74.083.076,76
# 705                     26000 - Ministério da Educação   R$ 46.567.972,57
# 706               39000 - Ministério da Infraestrutura   R$ 36.969.835,21
# 707               39000 - Ministério da Infraestrutura   R$ 29.248.935,28
# 708               39000 - Ministério da Infraestrutura    R$ 7.058.257,22
#
# [709 rows x 2 columns]

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
wb = gc.open_by_key('1JuitRIy4d1hZJAiM8guKBNMfnCC_5y4OWX3vQzOPpSQ')
ws = wb.worksheet('Valor Restos a Pagar')

# get_all_values gives a list of rows.
rows = ws.get_all_values()


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
#                                                      0                     1
# 0                                       Órgão Superior  Valor Restos a Pagar
# 1                     63000 - Advocacia-Geral da União       R$ 1.320.862,24
# 2                     63000 - Advocacia-Geral da União         R$ 303.506,63
# 3                     63000 - Advocacia-Geral da União       R$ 1.486.439,68
# 4    24000 - Ministério da Ciência, Tecnologia, Ino...       R$ 2.483.598,24
# ..                                                 ...                   ...
# 704                     26000 - Ministério da Educação       R$ 5.040.885,44
# 705                     26000 - Ministério da Educação         R$ 902.716,36
# 706               39000 - Ministério da Infraestrutura       R$ 3.261.710,61
# 707               39000 - Ministério da Infraestrutura      R$ 11.557.545,85
# 708               39000 - Ministério da Infraestrutura       R$ 1.506.339,15
#
# [709 rows x 2 columns]

# %%
vemax = 339322796039,13

vlmax = 396644643343,24

vpmax = 396644183297,60

vrmax = 324424667,93


# pacotes necessários
import numpy as np
import matplotlib.pyplot as plt

Max = ['vemax','vlmax', 'vpmax', 'vrmax']
Valores = [33932279604, 39664464335, 39664418300, 324424667]

plt.bar(Max, Valores, color='red')

plt.ylabel('Valores')
plt.xlabel('Máximos')
plt.title('Valores Empenhados')

plt.show()

# %% [markdown]
# É facilmente perceptível a discrepância numérica entre o valor de "restos  a pagar" e os demais valores, e isso se da pela data em que tais dados foram coletados, que no caso são de agosto, setembro e outubro, com o decorrer do ano e o acúmulo de pendências do governo tal valor tende a aumentar consideravelmente.

# %%
vemin = -1158545934,60

vlmin = 4532,00

vpmin = 1429,77

vrmin = -5664055,46

# pacotes necessários
import numpy as np
import matplotlib.pyplot as plt

Min = ['vemin', 'vlmin', 'vpmin', 'vrmin']
Valores = [-115855, 4532, 1429, -5665]

plt.bar(Min, Valores, color='Blue')

plt.ylabel('Valores')
plt.xlabel('Mínimos')
plt.title('Valores Empenhados')

plt.show()

# %% [markdown]
# A partir dos valores analisados é possível perceber uma enorme discrepância referente ao valor empenhado mínimo e os outros valores, isso se dá devido principalmente a natureza dos outros valores, enquanto todo valor gasto já é liquidado e pago o valor empenhado negativo é uma pratica pouco comum e devido a isso suas dimensões mínimas são extremamente maiores.
